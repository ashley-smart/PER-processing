# %%
## to compare individual video frames and see if there are any duplicates. 

import math
import csv 
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import path
import scipy as scipy
import scipy.io
import cv2

import os
os.listdir(os.getcwd())

import json as json
import pickle as pickle

import peaks


def error(img1, img2):
   diff = cv2.subtract(img1, img2)
   err = np.sum(diff**2)
   mse = err/(float(h*w))
   msre = np.sqrt(mse)
   return mse, diff

# %%
date = '20230512'

raw_path = "E:/bruker_vid_2023/" + str(date) + "/analysis/"  ##JPEGS AND ROIS MUST BE SAVED IN SEPERATE ANALYSIS FOLDER

for fly_dir in os.listdir(raw_path):
    dir_number = peaks.find_number(peaks.find_fly_string(fly_dir), dash = 'y')
    #print('fly dir number:', dir_number)
    if len(dir_number) == 0:
        raise Exception(f"ERROR: THERE IS NO DIRECTORY NUMBER FOR...{fly_dir}")
    if '.zip' not in fly_dir and '.txt' not in fly_dir and 'Roi' not in fly_dir:
        print('fly dir:', fly_dir)
        jpeg_path = os.path.join(raw_path, fly_dir)
        print('jpeg path', jpeg_path)

        if os.path.exists(jpeg_path):
            jpeg_file_names = os.listdir(jpeg_path)
            sorted_jpeg_file_names = sorted(jpeg_file_names)
            ##just verification that sorting process works ok
            print('sorted', sorted_jpeg_file_names[0:5])

            ## actual testing to see if one frame and the next are identical
            for i in range(len(sorted_jpeg_file_names)-1):
            first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
            second_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i+1])
            img1 = cv2.imread(first_frame)
            img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
            h, w = img1.shape
            img2 = cv2.imread(second_frame)
            img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

            match_error12, diff12 = error(img1, img2)
            if match_error12 < 0.1:
                print(f'frame {first_frame} and frame {second_frame} match')
                print(f'error value = {match_error12}')  #if identical this will be == 0
# Out:
# fly dir number: 1
# fly dir: fly1
# jpeg path E:/bruker_vid_2023/20230512/analysis/fly1
# sorted ['V01-frame_0000001.jpg', 'V01-frame_0000002.jpg', 'V01-frame_0000003.jpg', 'V01-frame_0000004.jpg', 'V01-frame_0000005.jpg']
# fly dir number: 2
# fly dir: fly2
# jpeg path E:/bruker_vid_2023/20230512/analysis/fly2
# sorted ['V02-frame_0000001.jpg', 'V02-frame_0000002.jpg', 'V02-frame_0000003.jpg', 'V02-frame_0000004.jpg', 'V02-frame_0000005.jpg']
# fly dir number: 2
# fly dir number: 1
# fly dir number: 1
# fly dir number: 2
# fly dir number: 2

# %%
jpeg_name_set = sorted_jpeg_file_names[0:5]
print(type(jpeg_name_set))
print(jpeg_name_set[3])
jpeg_name_set.insert(3, jpeg_name_set[3])
print(jpeg_name_set)
print(len(jpeg_name_set))
# Out:
# <class 'list'>
# V02-frame_0000004.jpg
# ['V02-frame_0000001.jpg', 'V02-frame_0000002.jpg', 'V02-frame_0000003.jpg', 'V02-frame_0000004.jpg', 'V02-frame_0000004.jpg', 'V02-frame_0000005.jpg']
# 6

# %%
jpeg_name_set = sorted_jpeg_file_names[0:5]
print(type(jpeg_name_set))
print(jpeg_name_set[3])
jpeg_name_set.insert(3, jpeg_name_set[3])
print(jpeg_name_set)
print(len(jpeg_name_set))

frame_file_0 = os.path.join(jpeg_path, jpeg_name_set[0])
frame_file_1 = os.path.join(jpeg_path, jpeg_name_set[1])
frame_file_2 = os.path.join(jpeg_path, jpeg_name_set[2])


img1 = cv2.imread(frame_file_0)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
print(img1.shape)
h, w = img1.shape

img2 = cv2.imread(frame_file_1)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
img3 = cv2.imread(frame_file_2)
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

def error(img1, img2):
   diff = cv2.subtract(img1, img2)
   err = np.sum(diff**2)
   mse = err/(float(h*w))
   msre = np.sqrt(mse)
   return mse, diff

match_error12, diff12 = error(img1, img2)
match_error13, diff13 = error(img1, img3)
match_error23, diff23 = error(img2, img3)

# print(match_error12)
# print(match_error13)
# print(match_error23)

##this is a test to make sure it will find identical frames
for i in range(len(jpeg_name_set)-1):
   first_frame = os.path.join(jpeg_path, jpeg_name_set[i])
   second_frame = os.path.join(jpeg_path, jpeg_name_set[i+1])
   img1 = cv2.imread(first_frame)
   img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
   h, w = img1.shape
   img2 = cv2.imread(second_frame)
   img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

   match_error12, diff12 = error(img1, img2)
   if match_error12 < 0.1:
      print(f'FOR THE TEST! frame {first_frame} and frame {second_frame} match')
      print(match_error12)


## actual testing
for i in range(len(sorted_jpeg_file_names)-1):
   first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
   second_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i+1])
   img1 = cv2.imread(first_frame)
   img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
   h, w = img1.shape
   img2 = cv2.imread(second_frame)
   img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

   match_error12, diff12 = error(img1, img2)
   if match_error12 < 0.1:
      print(f'frame {first_frame} and frame {second_frame} match')
      print(match_error12)
# Out:
# <class 'list'>
# V02-frame_0000004.jpg
# ['V02-frame_0000001.jpg', 'V02-frame_0000002.jpg', 'V02-frame_0000003.jpg', 'V02-frame_0000004.jpg', 'V02-frame_0000004.jpg', 'V02-frame_0000005.jpg']
# 6
# (1080, 1440)
# FOR THE TEST! frame E:/bruker_vid_2023/20230512/analysis/fly2\V02-frame_0000004.jpg and frame E:/bruker_vid_2023/20230512/analysis/fly2\V02-frame_0000004.jpg match
# 0.0

# %%
## choose 10 points at random in image
##get a matrix of 10 points x frames
## do a subtraction np.diff between adjacent frames
## sum over the pixels and see if they are zero for a diff

jpeg_name_set = sorted_jpeg_file_names[0:5]
print(type(jpeg_name_set))
print(jpeg_name_set[3])
jpeg_name_set.insert(3, jpeg_name_set[3])
print(jpeg_name_set)
print(len(jpeg_name_set))

frame_file_0 = os.path.join(jpeg_path, jpeg_name_set[0])
frame_file_1 = os.path.join(jpeg_path, jpeg_name_set[1])
frame_file_2 = os.path.join(jpeg_path, jpeg_name_set[2])


img1 = cv2.imread(frame_file_0)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
print(img1.shape)
x, y = img1.shape

img2 = cv2.imread(frame_file_1)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
img3 = cv2.imread(frame_file_2)
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

print(np.shape(img1))
print(img3[47][47])

print(np.max(img3))
print(np.min(img3))

number_of_pixels = 10

random_x = np.random.randint(0,x, size = number_of_pixels)
random_y = np.random.randint(0,y, size = number_of_pixels)
pts_1 = img1[random_x, random_y]
pts_2 = img2[random_x, random_y]
pts_3 = img3[random_x, random_y]
print(pts_1)
print(pts_2)

matrix = np.array([pts_1, pts_2, pts_3])

print(matrix)
print(np.shape(matrix))
print(np.diff(matrix, axis = 0))

all_pts = []
random_x = np.random.randint(0,x, size = number_of_pixels)
random_y = np.random.randint(0,y, size = number_of_pixels)
for i in range(len(jpeg_name_set)):
    first_frame = os.path.join(jpeg_path, jpeg_name_set[i])
    #second_frame = os.path.join(jpeg_path, jpeg_name_set[i+1])
    img1 = cv2.imread(first_frame)
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    x, y = img1.shape
    # img2 = cv2.imread(second_frame)
    # img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

    ##get random pixels
    pts = img1[random_x, random_y]
    #pts_2 = img2[random_x, random_y]
    all_pts.append(pts)

print(np.shape(all_pts))
pts_diff = np.diff(all_pts, axis = 0)

print(np.shape(pts_diff))
sum = np.sum(pts_diff, axis = 1)
print(np.where(sum == 0))
print(jpeg_name_set)
# Out:
# <class 'list'>
# V01-frame_0000004.jpg
# ['V01-frame_0000001.jpg', 'V01-frame_0000002.jpg', 'V01-frame_0000003.jpg', 'V01-frame_0000004.jpg', 'V01-frame_0000004.jpg', 'V01-frame_0000005.jpg']
# 6
# (1080, 1440)
# (1080, 1440)
# 6
# 255
# 0
# [ 4  4  4 35  3  3  3  6  2  3]
# [ 3  3  3 33  3  3  3  6  3  3]
# [[ 4  4  4 35  3  3  3  6  2  3]
#  [ 3  3  3 33  3  3  3  6  3  3]
#  [ 3  3  4 33  5  3  3  6  3  4]]
# (3, 10)
# [[255 255 255 254   0   0   0   0   1   0]
#  [  0   0   1   0   2   0   0   0   0   1]]
# (6, 10)
# (5, 10)
# (array([3], dtype=int64),)
# ['V01-frame_0000001.jpg', 'V01-frame_0000002.jpg', 'V01-frame_0000003.jpg', 'V01-frame_0000004.jpg', 'V01-frame_0000004.jpg', 'V01-frame_0000005.jpg']

# %%
##choosing random pixels to compare
##if the same frame then the difference for that frame == 0 all the way across

number_of_pixels = 10
all_pts = []
random_x = np.random.randint(0,x, size = number_of_pixels)
random_y = np.random.randint(0,y, size = number_of_pixels)
for i in range(len(sorted_jpeg_file_names)):
    first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
    img1 = cv2.imread(first_frame)
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    x, y = img1.shape

    ##get random pixels
    pts = img1[random_x, random_y]
    all_pts.append(pts)

print(np.shape(all_pts))
print(np.shape(all_pts))
pts_diff = np.diff(all_pts, axis = 0)

print(np.shape(pts_diff))
sum = np.sum(pts_diff, axis = 1)
print(np.where(sum == 0))
# Out:
# (93217, 10)
# (93217, 10)
# (93216, 10)
# (array([   18,    56,    79, ..., 93120, 93165, 93167], dtype=int64),)

# %%
zeros = np.where(sum == 0)[0]
print(len(zeros))
print(len(sum))

##check the zeros frames to see if they are still zeros with new pixels 
# need to check the next frame to compare
number_of_pixels = 30
all_pts = []
all_diff = []
random_x = np.random.randint(0,x, size = number_of_pixels)
random_y = np.random.randint(0,y, size = number_of_pixels)
for i in zeros:
    first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
    next_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i + 1])
    img1 = cv2.imread(first_frame)
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    img2 = cv2.imread(next_frame)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    x, y = img1.shape

    ##get random pixels
    pts1 = img1[random_x, random_y]
    pts2 = img2[random_x, random_y]
    all_pts.append(pts1)
    all_pts.append(pts2)
    diff = pts1 - pts2
    all_diff.append(diff)

#print(all_diff)
print(np.shape(all_diff))
zero_sum = np.sum(all_diff, axis = 1)
print(np.where(zero_sum == 0))
# Out:
# 1864
# 93216

# %%
# Out:
# (1864, 30)
# (array([835], dtype=int64),)

# %%
jpeg_path = os.path.join(raw_path, 'fly1')
print('jpeg path', jpeg_path)

jpeg_file_names = os.listdir(jpeg_path)
sorted_jpeg_file_names = sorted(jpeg_file_names)

## actual testing

##frame to check individually, the entire image
i = 835

first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
second_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i+1])
img1 = cv2.imread(first_frame)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
h, w = img1.shape
img2 = cv2.imread(second_frame)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

match_error12, diff12 = error(img1, img2)
if match_error12 < 0.1:
    print(f'frame {first_frame} and frame {second_frame} match')
    print(match_error12)
print(match_error12)
# Out:
# jpeg path E:/bruker_vid_2023/20230512/analysis/fly1
# 0.37827289094650207

# %%
## get jpeg files 

date = '20230630'

raw_path = "E:/bruker_vid_2023/" + str(date) + "/analysis/"  ##JPEGS AND ROIS MUST BE SAVED IN SEPERATE ANALYSIS FOLDER


number_of_pixels = 25

all_fly_sums = []
for fly_dir in os.listdir(raw_path):
    dir_number = peaks.find_number(peaks.find_fly_string(fly_dir), dash = 'y')
    #print('fly dir number:', dir_number)
    if len(dir_number) == 0:
        raise Exception(f"ERROR: THERE IS NO DIRECTORY NUMBER FOR...{fly_dir}")
    if '.zip' not in fly_dir and '.txt' not in fly_dir and 'Roi' not in fly_dir:
        print('fly dir:', fly_dir)
        jpeg_path = os.path.join(raw_path, fly_dir)
        print('jpeg path', jpeg_path)

        if os.path.exists(jpeg_path):
            jpeg_file_names = os.listdir(jpeg_path)
            sorted_jpeg_file_names = sorted(jpeg_file_names)
            ##just verification that sorting process works ok
            print('sorted', sorted_jpeg_file_names[0:5])

            
            all_pts = []
            first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[0])
            img1 = cv2.imread(first_frame)
            img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
            x, y = img1.shape
            random_x = np.random.randint(0,x, size = number_of_pixels)
            random_y = np.random.randint(0,y, size = number_of_pixels)
            for i in range(len(sorted_jpeg_file_names)):
                first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
                img1 = cv2.imread(first_frame)
                img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

                ##get random pixels
                pts = img1[random_x, random_y]
                all_pts.append(pts)

            print(np.shape(all_pts))
            print(np.shape(all_pts))
            pts_diff = np.diff(all_pts, axis = 0)

            print(np.shape(pts_diff))
            sum = np.sum(pts_diff, axis = 1)
            print(np.where(sum == 0))
            all_fly_sums.append(sum)



            # ## actual testing to see if one frame and the next are identical
            # for i in range(len(sorted_jpeg_file_names)-1):
            #     first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
            #     second_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i+1])
            #     img1 = cv2.imread(first_frame)
            #     img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
            #     h, w = img1.shape
            #     img2 = cv2.imread(second_frame)
            #     img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

            #     match_error12, diff12 = error(img1, img2)
            #     if match_error12 < 0.1:
            #         print(f'frame {first_frame} and frame {second_frame} match')
            #         print(f'error value = {match_error12}')  #if identical this will be == 0
# Out:
# fly dir: fly1
# jpeg path E:/bruker_vid_2023/20230630/analysis/fly1
# sorted ['V01-frame_0000001.jpg', 'V01-frame_0000002.jpg', 'V01-frame_0000003.jpg', 'V01-frame_0000004.jpg', 'V01-frame_0000005.jpg']
# (191651, 25)
# (191651, 25)
# (191650, 25)
# (array([  2499,   2970,   9162,  11523,  11787,  16059,  19712,  21257,
#         33391,  37348,  54630,  66357,  75296,  81371,  93334, 105447,
#        124647, 135851, 139069, 141612, 146123, 146501, 153599, 157289,
#        158853, 160123, 183426], dtype=int64),)
# fly dir: fly2
# jpeg path E:/bruker_vid_2023/20230630/analysis/fly2
# sorted ['V02-frame_0000001.jpg', 'V02-frame_0000002.jpg', 'V02-frame_0000003.jpg', 'V02-frame_0000004.jpg', 'V02-frame_0000005.jpg']
# (224912, 25)
# (224912, 25)
# (224911, 25)
# (array([   806,   7482,   7904,  13524,  14325,  14803,  16145,  17678,
#         17840,  20263,  21250,  22734,  22736,  23631,  27177,  30431,
#         31773,  32386,  33557,  41731,  42082,  42767,  44917,  45825,
#         46794,  46860,  51387,  51548,  53392,  55920,  58709,  60408,
#         64580,  64879,  66735,  67352,  68533,  70005,  71235,  71810,
#         74083,  74427,  75936,  76342,  76360,  76596,  76623,  77207,
#         77430,  78501,  79381,  79762,  82878,  83765,  84099,  84514,
#         85148,  85188,  85351,  85455,  87613,  88466,  88928,  90975,
#         96213,  97782,  98985,  99481, 100194, 100728, 100849, 101301,
#        102380, 102381, 103022, 103957, 104620, 104830, 105592, 105769,
#        106551, 111532, 111680, 111738, 112616, 113149, 113279, 115188,
#        115526, 116205, 118950, 120419, 120490, 120957, 121192, 122931,
#        124312, 125427, 127742, 128012, 128255, 129275, 130088, 131969,
#        132264, 132846, 133162, 133291, 133534, 135545, 137849, 137862,
#        138262, 139883, 140112, 143161, 145215, 147046, 148124, 149754,
#        149820, 149885, 150172, 151306, 152116, 153320, 154441, 155632,
#        158679, 158816, 162240, 162316, 163944, 165332, 165621, 166025,
#        169332, 170966, 171775, 172844, 173656, 175021, 176626, 177472,
#        180721, 180916, 183074, 183632, 183753, 184206, 184284, 186289,
#        187456, 187674, 188276, 188748, 189323, 189379, 191884, 193242,
#        193265, 194234, 194581, 195881, 196704, 197140, 198262, 198536,
#        201930, 202273, 203742, 204668, 209727, 210305, 211269, 214000,
#        214111, 214825, 215044, 215270, 216958, 217009, 217205, 219008,
#        220412, 221648, 221785, 222022, 223321, 223459], dtype=int64),)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 12
#      10 all_fly_sums = []
#      11 for fly_dir in os.listdir(raw_path):
# ---> 12     dir_number = peaks.find_number(peaks.find_fly_string(fly_dir), dash = 'y')
#      13     #print('fly dir number:', dir_number)
#      14     if len(dir_number) == 0:
#
# File c:\Users\ashsm\OneDrive\Documents\Python Scripts\PER-processing\PER-processing\peaks.py:133, in find_fly_string(string)
#     131 def find_fly_string(string):
#     132     """things after fly will be returned as string"""
# --> 133     post_fly_string = string.split("fly",1)[1]
#     134     return post_fly_string
#
# IndexError: list index out of range

# %%
##more thorough secondary comparison of the frames in question

print(len(all_fly_sums))
for fly_i in range(len(all_fly_sums)):
    zero_frames = np.where(all_fly_sums[fly_i] == 0)[0]
    number_of_pixels = 50
    all_pts = []
    all_diff = []
    random_x = np.random.randint(0,x, size = number_of_pixels)
    random_y = np.random.randint(0,y, size = number_of_pixels)
    for i in zero_frames:
        fly_dir = 'fly' + str(fly_i + 1)
        jpeg_path = os.path.join(raw_path, fly_dir)
        #print('jpeg path', jpeg_path)

        
        jpeg_file_names = os.listdir(jpeg_path)
        sorted_jpeg_file_names = sorted(jpeg_file_names)

        first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
        next_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i + 1])
        img1 = cv2.imread(first_frame)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2 = cv2.imread(next_frame)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
        x, y = img1.shape

        ##get random pixels
        pts1 = img1[random_x, random_y]
        pts2 = img2[random_x, random_y]
        all_pts.append(pts1)
        all_pts.append(pts2)
        diff = pts1 - pts2
        all_diff.append(diff)

    #print(all_diff)
    print(np.shape(all_diff))
    zero_sum = np.sum(all_diff, axis = 1)
    print(np.where(zero_sum == 0))
# Out:
# 2
# (27, 50)
# (array([], dtype=int64),)
# (190, 50)
# (array([], dtype=int64),)

# %%
# jpeg_path = os.path.join(raw_path, 'fly1')
# print('jpeg path', jpeg_path)

# jpeg_file_names = os.listdir(jpeg_path)
# sorted_jpeg_file_names = sorted(jpeg_file_names)

# ## actual testing
# for i in range(len(sorted_jpeg_file_names)-1):
#    first_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i])
#    second_frame = os.path.join(jpeg_path, sorted_jpeg_file_names[i+1])
#    img1 = cv2.imread(first_frame)
#    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
#    h, w = img1.shape
#    img2 = cv2.imread(second_frame)
#    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#    match_error12, diff12 = error(img1, img2)
#    if match_error12 < 0.1:
#       print(f'frame {first_frame} and frame {second_frame} match')
#       print(match_error12)
# Out:
# jpeg path E:/bruker_vid_2023/20230512/analysis/fly1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 14
#      12 img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
#      13 h, w = img1.shape
# ---> 14 img2 = cv2.imread(second_frame)
#      15 img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
#      17 match_error12, diff12 = error(img1, img2)
#
# KeyboardInterrupt:
